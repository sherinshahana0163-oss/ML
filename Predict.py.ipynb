# %% [markdown]
# ### Predict.py

# %%
import streamlit as st
import pickle

# %%
st.header("Titanic")
# Out:
# 2026-02-24 10:38:20.126 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-24 10:38:20.873
# ...
#   command:
#
#     streamlit run C:\Users\Shahana Sherin\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-24 10:38:20.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
